# %%
class Obj_Base:
    def __init__(self,track):
        self.num = 0
        #self.count = 0
        self.track = track
    def change_ct(self):
        temp = []
        for _ in range(self.track):
            temp.append(self.num)
            self.num += 1  
        print(f"The value of num is {self.num}")
        return temp  

    # def __setattr__(self, name, value):
    #      pass

# %%
o1 = Obj_Base(5)
o1.change_ct()
# Out:
# The value of num is 5
# [0, 1, 2, 3, 4]
