# %%
class Obj_Base:
    def __init__(self,track):
        self.num = 0
        self.count = 0
        self.track = track
    def change_ct(self):
        for _ in range(self.track):
            self.num += 1  
        print(f"The value of num is {self.num}")  

    def __setattr__(self, name, value):
         pass

# %%
o1 = Obj_Base(5)
o1.num
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 2
#       1 o1 = Obj_Base(5)
# ----> 2 o1.num
#
# AttributeError: 'Obj_Base' object has no attribute 'num'
