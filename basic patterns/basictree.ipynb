# %%
# Basic Tree implementation
class TNode:
    def __init__(self,data):
        self.data = data
        self.right = None 
        self.left = None 
class Tree:
    # def __init__(self, data):
    #     self.createNode(data)
    def createNode(self,data): # Use this as constructor for root node
        self.tNode = TNode(data)
        self.tNode.left = None
        self.tNode.right = None
        return tNode    
    def addNode(self, dataIn):
        # If root - left and right is not None. Traverse according to the size of data
        
        # Check the data if its greater or lesser than root node
        if self.tNode.data > dataIn:
            pass
        if self.tNode.data < dataIn:
            pass
        # if the data is greater than update the right node
        # if the data is less than update the left node
         
        
    def removeNode(self, dataOut):
        pass
    def printDFS(self):
        pass
    def printBFS(self):
        pass

# %%
class node:
    def __init__(self, data):
        self.data = data
    def add(self, num):
        self.data = self.data + num
n = node(9)
print(n.data)
n.add(5)
print(n.data)
# Out:
# 9
# 14

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.left = None
        self.right = None
# Creating Node
tree = Node(5)
ltree = Node(3)
rtree = Node(7)
# connecting Node
tree.left = ltree # left connection
tree.right = rtree # right Node connection
# Traveling from tree node
print("Tree data", tree.data)
print("lTree object", tree.left)
print("lTree data", tree.left.data)
print("rTree object", tree.right)
print("rTree data", tree.right.__dict__)
# Out:
# Tree data 5
# lTree object <__main__.Node object at 0x000001E66676B390>
# lTree data 3
# rTree object <__main__.Node object at 0x000001E66676B9D0>
# rTree data {'data': 7, 'left': None, 'right': None}
