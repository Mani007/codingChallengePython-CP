# %%
# Basic Tree implementation
class TNode:
    def __init__(self,data):
        self.data = data
        self.right = None 
        self.left = None 
class Tree:
    def __init__(self, data):
        self.createNode(data)
    def createNode(self,data):
        self.tNode = TNode(data)
        pass    
    def addNode(self):
        pass
    def removeNode(self):
        pass
    def printDFS(self):
        pass
    def printBFS(self):
        pass

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.left = None
        self.right = None
# Creating Node
tree = Node(5)
ltree = Node(3)
rtree = Node(7)
# connecting Node
tree.left = ltree # left connection
tree.right = rtree # right Node connection
# Traveling from tree node
print("Tree data", tree.data)
print("lTree object", tree.left)
print("lTree data", tree.left.__dict__)
print("rTree object", tree.right)
print("rTree data", tree.right.__dict__)
# Out:
# Tree data 5
# lTree object <__main__.Node object at 0x000001E66676B750>
# lTree data {'data': 3, 'left': None, 'right': None}
# rTree object <__main__.Node object at 0x000001E66676B390>
# rTree data {'data': 7, 'left': None, 'right': None}
