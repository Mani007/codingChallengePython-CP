# %%
st = 'abcdefghi'
print(st)
# Out:
# abcdefghi

# %%
st = 'abcabcaabbccddee'
n = len(st)
# print(st[0:3])
left = 0
right = 1
res = []
while right<n:
    # for i in range(right+1):
    res.append(st[left:right])
    right += 1
print(res)
print(len(res))
# print(st[left])
# print(st[right])
# Out:
# ['a', 'ab', 'abc', 'abca', 'abcab', 'abcabc', 'abcabca', 'abcabcaa', 'abcabcaab', 'abcabcaabb', 'abcabcaabbc', 'abcabcaabbcc', 'abcabcaabbccd', 'abcabcaabbccdd', 'abcabcaabbccdde']
# 15
