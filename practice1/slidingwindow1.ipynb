# %%
st = 'abcdefghi'
print(st)
# Out:
# abcdefghi

# %%
st = 'abcabcaabbccddee'
n = len(st)
left = 0
right = n-1
window_size = 1
t = []
while left<right and window_size<n:
    for i in range(window_size):
        window_size += 1
        t.append(st[left])
        left += 1
           
print(t)
print(len(t))
        
    
# print(st[left])
# print(st[right])
# Out:
# ['ab', 'bc', 'ca', 'ab', 'bc', 'ca', 'aa', 'ab', 'bb', 'bc', 'cc', 'cd', 'dd', 'de', 'ee']
# 15
