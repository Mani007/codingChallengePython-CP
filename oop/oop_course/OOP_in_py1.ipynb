# %%
class Car:
    pass

# %% [markdown]
# ### Syntax for class
#
#     class <classname>:
#         # Write your code here

# %%
Car
# Out:
# __main__.Car

# %% [markdown]
# ## Objects

# %%
c1 = 2+5j  
print(type(c1)) 
print(c1.real)
print(c1.imag)
# Out:
# <class 'complex'>
# 2.0
# 5.0

# %%
class Car:
    pass
# creating object of class Car
swift = Car() # swift is the object of Car

# %%
print(type(swift))
# Out:
# <class '__main__.Car'>

# %%
a1 = int(2) # it is same as a1 = 2, 'int' is an built in class in python
a2 = 5  # object literals for builtin objects
print(a1)
print(a2)
# Out:
# 2
# 5

# %%
class Student:
    def __init__(self,name,roll_no,percentage):
        self.name = name
        self.roll_no = roll_no
        self.percentage = percentage
s1 = Student("ABC",21,95)
s1.name,s1.roll_no,s1.percentage
# Out:
# ('ABC', 21, 95)

# %%
class Student:
    def __init__(self,name:str,roll_no:int,percentage:float):
        self.name = name
        self.roll_no = roll_no
        self.percentage = percentage
    def study(self):
        print("DO NOT DISTURB I am " + str(self.playing()) + " and I am studying.!! ")
    def playing(self):
        print("I am " + self.name + " and I am PLAYING.!!")
        return self.name

# %%
s1 = Student("AAA",25,90.9)
s1.study()
# Out:
# I am AAA and I am PLAYING.!!
# DO NOT DISTURB I am AAA and I am studying.!!
