# %%
class Car:
    pass

# %% [markdown]
# ### Syntax for class
#
#     class <classname>:
#         # Write your code here

# %%
Car
# Out:
# __main__.Car

# %% [markdown]
# ## Objects

# %%
c1 = 2+5j  
print(type(c1)) 
print(c1.real)
print(c1.imag)
# Out:
# <class 'complex'>
# 2.0
# 5.0

# %%
class Car:
    pass
# creating object of class Car
swift = Car() # swift is the object of Car

# %%
print(type(swift))
# Out:
# <class '__main__.Car'>

# %%
a1 = int(2) # it is same as a1 = 2, 'int' is an built in class in python
a2 = 5  # object literals for builtin objects
print(a1)
print(a2)
# Out:
# 2
# 5

# %%
class Student:
    def __init__(self,name,roll_no,percentage):
        self.name = name
        self.roll_no = roll_no
        self.percentage = percentage
s1 = Student("ABC",21,95)
s1.name
# Out:
# 'ABC'
