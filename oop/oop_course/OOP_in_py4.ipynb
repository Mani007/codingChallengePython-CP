# %%
# Understand static variable in python
class Student:
    __schoolName = "KV" # class variable or static property
    def __init__(self,name):
        self.__name = name
    def getSchool():# We do not need self here as its static/class attribute
        return Student.__schoolName
    @staticmethod
    def getInstanceSchool(self):# We do not need self here as its static/class attribute
        return Student.__schoolName
s1 = Student("ABC")

# %%
Student.getSchool()
# Out:
# 'KV'

# %%
s1.getSchool() # cannot call this as its class method
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 s1.getSchool()
#
# TypeError: Student.getSchool() takes 0 positional arguments but 1 was given

# %%
s1.getInstanceSchool()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 s1.getInstanceSchool()
#
# AttributeError: 'Student' object has no attribute 'getInstanceSchool'
